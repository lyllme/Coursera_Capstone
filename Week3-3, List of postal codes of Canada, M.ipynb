# %%
import pandas as pd
df = pd.read_csv('canada3.csv')
# Out:
# (180, 3)

# %%
# deleting NaN cells, and count the remainings
df_noNaN = df.dropna(how='any', axis = 0)
df_noNaN.shape
# Out:
# (103, 3)

# %%
df2 = pd.read_csv('Geospatial_Coordinates.csv')
df2 = df2.rename(columns={'Postal Code': 'PostalCode'})
df_incidents = pd.merge(df_noNaN, df2, on='PostalCode', how='inner')
df_incidents
# Out:
#     PostalCode                                            Borough  \
# 0          M3A                                         North York
# 1          M4A                                         North York
# 2          M5A                                   Downtown Toronto
# 3          M6A                                         North York
# 4          M7A                                      Queen's Park
# ..         ...                                                ...
# 98         M8X                                          Etobicoke
# 99         M4Y                                   Downtown Toronto
# 100        M7Y  East Toronto, Business reply mail, Processing ...
# 101        M8Y                                          Etobicoke
# 102        M8Z                                          Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# ...

# %%
#!pip install folium==0.10.1
import folium
print(folium.__version__)
# Out:
# 0.10.1

# %%
# define the world map
world_map = folium.Map()

### type your answer here
tronto_latitude = 43.653226  
tronto_longitude = -79.383184 
# define the world map centered around Canada with a low zoom level
world_map = folium.Map(location=[tronto_latitude, tronto_longitude], zoom_start=10)

limit = 200
df_incidents = df_incidents.iloc[0:limit, :]

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_incidents.shape
# Out:
# (103, 5)

# %%
l = ["a", "b"]
l_replace = [s.replace("b", "a") for s in l]
l_replace
# Out:
# ['a', 'a']

# %%
changerow = []
for post in df_incidents.PostalCode:
    changerow.append('\n')
    
l_borough = []

l_borough = [s.replace(",", ",\n") for s in df_incidents.Borough]

    
l_popinfo = []
for post, changerow, borough in zip(df_incidents.PostalCode, changerow, l_borough):
    l_popinfo.append(''.join(post+changerow+borough))
    #print(l_popinfo)


    
#l_popinfo
# to dataframe
df_incidents['popinfo']= l_popinfo
df_incidents
# Out:
# C:\Users\k62te\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     PostalCode                                            Borough  \
# 0          M3A                                         North York
# 1          M4A                                         North York
# 2          M5A                                   Downtown Toronto
# 3          M6A                                         North York
# 4          M7A                                      Queen's Park
# ..         ...                                                ...
# 98         M8X                                          Etobicoke
# 99         M4Y                                   Downtown Toronto
# ...

# %% [markdown]
# # answer

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
#for lat, lng, label in zip(df_incidents.Latitude, df_incidents.Longitude, df_incidents.PostalCode):
for lat, lng, label in zip(df_incidents.Latitude, df_incidents.Longitude, df_incidents.popinfo):   
    # incidents.add_child(
    folium.Marker(
    location = [lat, lng],
    icon = None,
    popup=label,
    ).add_to(incidents)
        
# add incidents to map
world_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# --end of assignment--
